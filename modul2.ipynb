# %% [markdown]
# <a href="https://colab.research.google.com/github/tsaniarisqi/PCVK_Matrikulasi_2022/blob/main/modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Praktikum**

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img =np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(521,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Tugas No 1**

# %%
# channel Red-Green
img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img6[:,:,2] = np.zeros([img6.shape[0], img6.shape[1]])
plt.imshow(img6)

# %%
# channel Green-Blue
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img7[:,:,0] = np.zeros([img7.shape[0], img7.shape[1]])
plt.imshow(img7)

# %% [markdown]
# **Tugas 4**
# > Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.

# %%
img9=img3
cv.rectangle(img9,pt1=(100,100),pt2=(200,200),color=(0,0,255),thickness=10)
cv.rectangle(img9,pt1=(500,500),pt2=(400,200),color=(0,255,255),thickness=10)
cv.rectangle(img9,pt1=(300,250),pt2=(320,120),color=(0,255,0),thickness=10)
cv.rectangle(img9,pt1=(300,250),pt2=(200,300),color=(255,255,0),thickness=10)
cv.rectangle(img9,pt1=(100,500),pt2=(50,550),color=(255,0,0),thickness=10)
plt.imshow(img9)

# %% [markdown]
# **Tugas 5**
# > Tampilkan image dengan posisi terbalik

# %%
img10 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img10)

# %% [markdown]
# **Tugas 6**
# > Buat rectangle dan circle pada bagian wajah dari image kitten

# %%
img11=img
img11=cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img11,pt1=(300,280),pt2=(500,90),color=(0,0,255),thickness=10)
cv.circle(img11,center=(400,190),radius=90,color=(0,255,0),thickness=10)

plt.imshow(img11)
